# %% [markdown]
# # SOK-1006 Arbeidskrav (3)
# Notat; funksjonene på feil akser (se oppgave 5).

# %%
# Laster inn pakker.
import sympy as sp
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import Markdown

# %%
# Definerer ett intervall mellom 0-100.
x_1 = np.linspace(0, 1000, 1000)

# %%
# Lager et preset for å enklere lage figuren senere.
# Hentet fra "forsmak mappe 1".
def create_ax():
                fig, ax = plt.subplots()
                ax.set_ylabel('Kvantum', loc='top')
                ax.set_xlabel('Pris', loc='right')
                ax.set_title("Markedslikevekt")
                ax.set(xlim=(0,200))
                ax.set(ylim=(0,520))
                ax.spines['top'].set_color('none')
                ax.spines['right'].set_color('none')
                
                return fig, ax

# %%
# Definerer etterspørselsfunksjonen.
def dem(p):
    return 500 - 3.2 * p

# Definerer tilbudsfunksjonen.
def sup(p, t):
    return 4.3*(p-t) - 100

# %% [markdown]
# #### Oppgave 1

# %%
# Definerer symboler jeg ønsker å bruke i utregningen.
p, t, x = sp.symbols("p t x")

# Definerer likningen for likevekt.
eq_01 = sp.Eq(dem(p), sup(p, t))

# %%
# Finner likevekstpris.
eq_pr = sp.solve(eq_01, p)

# Finner likevekstkvantum.
eq_qu = dem(eq_pr[0])

# %%
# Skriver ut svaret på oppgave 1.
print("Likevektspris for alle verdier av t er " + str(eq_pr[0]))
print("Likevektskvantum for alle verdier av t er " + str(eq_qu))
# Out:
# Likevektspris for alle verdier av t er 0.573333333333333*t + 80.0
# Likevektskvantum for alle verdier av t er 244.0 - 1.83466666666667*t

# %% [markdown]
# #### Oppgave 2

# %%
# Finner konsumentoverskudd.
con_pr = sp.integrate(dem(p) - eq_pr[0], (p, 0, eq_qu))

# Finner produsentoverskudd.
prod_pr = sp.integrate(eq_qu - sup(p, t), (p, 0, eq_qu))

# Finner avgiftproveny.
tax_rev = sp.integrate(t, (p, 0, eq_qu))

# %%
# Skriver ut svaret på oppgave 2.
print("Konsumentoverskuddet kan utrykkes som: " + str(con_pr))
print("Produsentoverskuddet kan utrykkes som: " + str(prod_pr))
print("Avgiftprovenyen kan utrykkes som: " + str(tax_rev))
# Out:
# Konsumentoverskuddet kan utrykkes som: -95257.6*(1 - 0.00751912568306011*t)**2 + (244.0 - 1.83466666666667*t)*(420.0 - 0.573333333333333*t)
# Produsentoverskuddet kan utrykkes som: -128002.4*(1 - 0.00751912568306011*t)**2 + (244.0 - 1.83466666666667*t)*(2.46533333333333*t + 344.0)
# Avgiftprovenyen kan utrykkes som: t*(244.0 - 1.83466666666667*t)

# %% [markdown]
# #### Oppgave 3

# %%
# Definerer likningen for likevekt med t = 0.
eq_tzero = sp.Eq(dem(p),sup(p, 0))

# Finner likevektpris.
eq_tzero_p = sp.solve(eq_tzero, p)

# Finner likevekstkvantum.
eq_tzero_k = dem(eq_tzero_p[0])

# Definerer et intervall fra 0-likevekt.
x_2 = np.linspace(0, 80, 100)
x_3 = np.linspace(80,158, 100)

# %%
eq_tzero_k
# Out:
# 244.000000000000

# %%
# Henter akse preset.
fig, ax = create_ax()

# Tegner inn tilbud og etterspørsel.
ax.plot(x_1, dem(x_1),    color = "blue",  label = "Etterspørsel")
ax.plot(x_1, sup(x_1, 0), color = "green", label = "Tilbud ekskl tilbud") 

# Tegner inn likevekt.
ax.vlines(eq_tzero_p, 0, dem(eq_tzero_p[0]), color = "grey", linestyle = "--")
ax.hlines(eq_tzero_k, 0, eq_tzero_p,         color = "grey", linestyle = "--")
ax.plot(eq_tzero_p, eq_tzero_k,              color = "grey", marker = "o")

# Fyller inn området til KO og PO.
ax.fill_between(x_3, 0, dem(x_3), color = "green", alpha = 0.5, label = "KO")
ax.fill_between(x_2, 0, sup(x_2,0), color = "red", alpha = 0.5, label = "PO")

# Legger til legend.
ax.legend()

# %% [markdown]
# #### Oppgave 4

# %%
# Definerer likningen for likevekt med t = 4.
eq_tfour = sp.Eq(dem(p),sup(p, 4))

# Finner likevektpris.
eq_tfour_p = sp.solve(eq_tfour, p)

# Finner likevekstkvantum.
eq_tfour_k = dem(eq_tfour_p[0])

# Definerer et intervall fra 0-likevekt.
x_4 = np.linspace(0, 236.661, 100)
x_5 = np.linspace(78, 82.293, 100)

# %%
eq_tfour_k
# Out:
# 236.661333333333

# %%
# Tegner inn t = 4.
ax.plot(x_1, sup(x_1, 4), color = "orange", label = "Tilbud inkl. tilbud") 

# Fyller inn området for avgiftproveny.
ax.fill_between(x_5, 0, 236.66, color = "purple", label = "Avgift", alpha = 0.7)

# Oppdaterer legend.
ax.legend()

# Viser figuren
fig

# %% [markdown]
# #### Oppgave 5

# %%
tbl=f"""
|                     | Før avgift            |Etter avgift    | Endring (etter avgift-før avgift)|
| :-------------------| :----------------------------------------|:-------------|:---------------|
| Konsumentpris       |  ${round(eq_tzero_p[0])}$                |${round(eq_tfour_p[0],2)}$              | ${round(eq_tfour_p[0]-eq_tzero_p[0],2)}$   |
|Produsentpris        |  ${round(eq_tzero_p[0])}$                |${round(eq_tfour_p[0]-4,2)}$            | ${round(eq_tfour_p[0]-4-eq_tzero_p[0],2)}$ |
|Kvantum              |  ${round(eq_tzero_k)}$                   |${round(eq_tfour_k,2)}$                 | ${round(eq_tfour_k - eq_tzero_k, 2)}$      |  
"""
display(Markdown(tbl))
# Out:
# |                     | Før avgift            |Etter avgift    | Endring (etter avgift-før avgift)|
# | :-------------------| :----------------------------------------|:-------------|:---------------|
# | Konsumentpris       |  $80$                |$82.29$              | $2.29$   |
# |Produsentpris        |  $80$                |$78.29$            | $-1.71$ |
# |Kvantum              |  $244$                   |$236.66$                 | $-7.34$      |

# %% [markdown]
# #### Notat
# Så at det ikke blei riktig på resten av oppgave 5 siden jeg har jobba med motsatte akser (pris skulle egt. hvert på y-aksen for å gjøre det enklere).
